# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ## Import Data

# %%
data=pd.read_csv(r'C:\Users\kale\Desktop\data sets\SampleSuperstore.csv')
data
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %% [markdown]
# ### Information about data

# %%
data.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit Profit/Loss
# 0      0.00   41.9136      Profit
# ...

# %%
data.shape           # shape of data
# Out:
# (9994, 14)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
#  13  Profit/Loss   9994 non-null   object
# dtypes: float64(3), int64(2), object(9)
# memory usage: 1.1+ MB

# %%
print(data.columns)  # column name in dataset
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Profit/Loss'],
#       dtype='object')

# %% [markdown]
# ## Statistical Analysis

# %%
data.describe()         # summary of dataset(mean,median,mode,quantiles)
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# ## Data cleaning- Checking for null values

# %%
#checking missing values in data
data.isna().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of       Ship Mode  Segment  Country   City  State  Postal Code  Region  \
# 0         False    False    False  False  False        False   False
# 1         False    False    False  False  False        False   False
# 2         False    False    False  False  False        False   False
# 3         False    False    False  False  False        False   False
# 4         False    False    False  False  False        False   False
# ...         ...      ...      ...    ...    ...          ...     ...
# 9989      False    False    False  False  False        False   False
# 9990      False    False    False  False  False        False   False
# 9991      False    False    False  False  False        False   False
# 9992      False    False    False  False  False        False   False
# 9993      False    False    False  False  False        False   False
#
#       Category  Sub-Category  Sales  Quantity  Discount  Profit  Profit/Loss
# ...

# %%
data.dropna(axis=0,inplace=True)  # drop null entries if present

# %%
data.shape
# Out:
# (9994, 14)

# %%
data.duplicated().sum()
# Out:
# 17

# %%
data.drop_duplicates()
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
data.shape
# Out:
# (9994, 14)

# %% [markdown]
# #### there no null values present in data.

# %%
data['Segment'].value_counts()
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %%
data.Category.value_counts()
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %% [markdown]
# ### Handling Outliers

# %%
plt.figure(figsize=(15,7))
sns.boxplot(data=data)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x='Sales',data=data)
# Out:
# <AxesSubplot:xlabel='Sales'>

# %% [markdown]
# ### Removing Outliers

# %%
Q1 = np.percentile(data['Sales'], 25,
                interpolation = 'midpoint')
  
Q3 = np.percentile(data['Sales'], 75,
                interpolation = 'midpoint')
IQR = Q3 - Q1
Q1,Q3,IQR
# Out:
# (17.28, 209.94, 192.66)

# %%
# Upper bound
upper=np.where(data['Sales']>=(Q3+1.5*IQR))
lower=np.where(data['Sales']<=(Q3-1.5*IQR))

# %%
data.drop(upper[0], inplace = True)        #Removing the Outliers
data.drop(lower[0], inplace = True)
print('New Shape:',data.shape )
# Out:
# New Shape: (8827, 14)

# %%
sns.boxplot(x='Sales',data=data)
# Out:
# <AxesSubplot:xlabel='Sales'>

# %%
sns.boxplot(x='Discount',data=data)
# Out:
# <AxesSubplot:xlabel='Discount'>

# %%
Q1 = np.percentile(data['Discount'], 25,interpolation = 'midpoint')
  
Q3 = np.percentile(data['Discount'], 75, interpolation = 'midpoint')
IQR = Q3 - Q1
print(Q1,Q3,IQR)
# Upper bound
upper=np.where(data['Discount']>=(Q3+1.5*IQR))
lower=np.where(data['Discount']<=(Q3-1.5*IQR))
data.drop(upper[0], inplace = True)        #Removing the Outliers
data.drop(lower[0], inplace = True)
print('New Shape:',data.shape)
sns.boxplot(x='Discount',data=data)
# Out:
# 0.0 0.2 0.2
# New Shape: (9072, 14)
# <AxesSubplot:xlabel='Discount'>

# %% [markdown]
# ## Data Visualization

# %%
# scatter Plot
sns.scatterplot(x='Sales',y='Profit',hue='Category',data=data)
plt.title('Scatter Plot')
# Out:
# Text(0.5, 1.0, 'Scatter Plot')

# %% [markdown]
# from above plot we conclude that as sales increases, profit increases and as sales decreases profit decreases.

# %%
sns.scatterplot(x='Sales',y='Discount',hue='Category',data=data)
plt.title('Scatter Plot')
# Out:
# Text(0.5, 1.0, 'Scatter Plot')

# %%
plt.figure(figsize=(15,8))
sns.countplot(x='Region',data=data)
# Out:
# <AxesSubplot:xlabel='Region', ylabel='count'>

# %%
# Pair Plot - Multivariate Analysis
figsize=(15,9)
sns.pairplot(data.drop(['Postal Code'],axis=1),hue='Sub-Category')

# %%
## Histogram
data.drop(['Postal Code'],axis=1).hist(bins=30,figsize=(15,7))
# Out:
# array([[<AxesSubplot:title={'center':'Sales'}>,
#         <AxesSubplot:title={'center':'Quantity'}>],
#        [<AxesSubplot:title={'center':'Discount'}>,
#         <AxesSubplot:title={'center':'Profit'}>]], dtype=object)

# %%
df=data.drop(['Postal Code'],axis=1)
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
sns.pairplot(df)

# %%
## Histogram and dist plot
plot = sns.FacetGrid(df, hue="Segment")
plot.map(sns.distplot, "Sales").add_legend()
  
plot = sns.FacetGrid(df, hue="Segment")
plot.map(sns.distplot, "Quantity").add_legend()
  
plot = sns.FacetGrid(df, hue="Segment")
plot.map(sns.distplot, "Discount").add_legend()
  
plot = sns.FacetGrid(df, hue="Segment")
plot.map(sns.distplot, "Profit").add_legend()
  
plt.show()
# Out:
# C:\Users\kale\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\kale\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
## Correlation
corr=data.corr()
corr
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# From heatmap
# Here ,
# 1)good positive correlation in sales and Profit.
#
# 2)very low correlation in quantity and Discount.
#
# 3)negative correlation in discount and and profit (means as discount increases profit decreases)

# %%
sns.countplot(data['Category'])
# Out:
# <AxesSubplot:xlabel='Category', ylabel='count'>

# %% [markdown]
# from visualization we observe that,
# 1)In maximum region in west and minimum region in south region.
#
# 2)In count plot we see maximum number of office supplies category and minimum number of technology.
#
# 3)As sales incerases profit increases and as sales decreases profit decreases
